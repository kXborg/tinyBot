# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import re
import pickle

print("Using TensorFlow version:", tf.__version__)
# Out:
# Using TensorFlow version: 2.10.1

# %%
# Load dataset
df = pd.read_csv("../dataset/tiny_chat_dataset.csv")
inputs = df['input_text'].astype(str).tolist()
targets = df['reply_text'].astype(str).tolist()

# Clean and prepare text
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9' ]+", '', text)
    return text.strip()

inputs = [clean_text(text) for text in inputs]
targets = ['<start> ' + clean_text(text) + ' <end>' for text in targets]

# %%
# Tokenization
VOCAB_SIZE = 1000
tokenizer = keras.preprocessing.text.Tokenizer(num_words=800, oov_token='OOV')
tokenizer.fit_on_texts(inputs + targets)

input_seq = tokenizer.texts_to_sequences(inputs)
target_seq = tokenizer.texts_to_sequences(targets)

max_len_in = max(len(seq) for seq in input_seq)
max_len_out = max(len(seq) for seq in target_seq)

input_seq = keras.preprocessing.sequence.pad_sequences(input_seq, maxlen=max_len_in, padding='post')
target_seq = keras.preprocessing.sequence.pad_sequences(target_seq, maxlen=max_len_out, padding='post')

word_index = tokenizer.word_index
index_word = {v: k for k, v in word_index.items()}

print(f"Vocabulary size: {len(word_index)}")
print(f"Max input length: {max_len_in}, max output length: {max_len_out}")
# Out:
# Vocabulary size: 139
# Max input length: 7, max output length: 14

# %%
# Create Seq2Seq Model (Encoder Decoder GRU)
EMBED_DIM = 64
HIDDEN_DIM = 128

# Encoder
encoder_inputs = keras.Input(shape=(None,))
enc_emb = layers.Embedding(VOCAB_SIZE, EMBED_DIM, mask_zero=True)(encoder_inputs)
encoder_outputs, state_h = layers.GRU(HIDDEN_DIM, return_state = True, dropout=0.2)(enc_emb)

# Decoder
decoder_inputs = keras.Input(shape=(None,))
dec_emb = layers.Embedding(VOCAB_SIZE, EMBED_DIM, mask_zero=True)(decoder_inputs)
decoder_gru = layers.GRU(HIDDEN_DIM, return_sequences=True, return_state=True)
decoder_outputs, _ = decoder_gru(dec_emb, initial_state=state_h)
decoder_dense = layers.Dense(VOCAB_SIZE, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

model.summary()

# Prepare shifted target for teacher forcing
target_input = target_seq[:, :-1]
target_output = target_seq[:, 1:]
target_output = np.expand_dims(target_output, -1)


# Train the model 
history = model.fit(
    [input_seq, target_input],
    target_output,
    batch_size=32,
    epochs=200,
    validation_split=0.1,
    verbose=1
)

# Save the model and Tokenizer
model.save('tiny_bot.h5')
with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

print("Model training completed and saved.")
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, None)]       0           []
#
#  input_19 (InputLayer)          [(None, None)]       0           []
#
#  embedding_12 (Embedding)       (None, None, 64)     64000       ['input_18[0][0]']
#
#  embedding_13 (Embedding)       (None, None, 64)     64000       ['input_19[0][0]']
#
#  gru_12 (GRU)                   [(None, 128),        74496       ['embedding_12[0][0]']
#                                  (None, 128)]
#
#  gru_13 (GRU)                   [(None, None, 128),  74496       ['embedding_13[0][0]',
#                                  (None, 128)]                     'gru_12[0][1]']
#
#  dense_5 (Dense)                (None, None, 1000)   129000      ['gru_13[0][0]']
#
# ==================================================================================================
# Total params: 405,992
# Trainable params: 405,992
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - 6s 532ms/step - loss: 4.1346 - val_loss: 4.1402
# Epoch 2/200
# 4/4 [==============================] - 0s 18ms/step - loss: 4.1190 - val_loss: 4.1192
# Epoch 3/200
# 4/4 [==============================] - 0s 16ms/step - loss: 4.0942 - val_loss: 4.0796
# Epoch 4/200
# 4/4 [==============================] - 0s 17ms/step - loss: 4.0450 - val_loss: 3.9925
# Epoch 5/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.9320 - val_loss: 3.7632
# Epoch 6/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.6140 - val_loss: 3.0934
# Epoch 7/200
# 4/4 [==============================] - 0s 18ms/step - loss: 2.8767 - val_loss: 2.4658
# Epoch 8/200
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3893 - val_loss: 2.2924
# Epoch 9/200
# 4/4 [==============================] - 0s 16ms/step - loss: 2.2266 - val_loss: 2.2267
# Epoch 10/200
# 4/4 [==============================] - 0s 16ms/step - loss: 2.1546 - val_loss: 2.1807
# Epoch 11/200
# 4/4 [==============================] - 0s 16ms/step - loss: 2.0930 - val_loss: 2.1291
# Epoch 12/200
# 4/4 [==============================] - 0s 16ms/step - loss: 2.0406 - val_loss: 2.0956
# Epoch 13/200
# 4/4 [==============================] - 0s 16ms/step - loss: 2.0007 - val_loss: 2.0793
# Epoch 14/200
# 4/4 [==============================] - 0s 15ms/step - loss: 1.9650 - val_loss: 2.0712
# Epoch 15/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9325 - val_loss: 2.0604
# Epoch 16/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9052 - val_loss: 2.0583
# Epoch 17/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.8865 - val_loss: 2.0606
# Epoch 18/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.8694 - val_loss: 2.0516
# Epoch 19/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.8496 - val_loss: 2.0253
# Epoch 20/200
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8308 - val_loss: 1.9882
# Epoch 21/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.8177 - val_loss: 1.9580
# Epoch 22/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.8003 - val_loss: 1.9430
# Epoch 23/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7863 - val_loss: 1.9396
# Epoch 24/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.7733 - val_loss: 1.9448
# Epoch 25/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7605 - val_loss: 1.9490
# Epoch 26/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.7479 - val_loss: 1.9443
# Epoch 27/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7348 - val_loss: 1.9144
# Epoch 28/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.7186 - val_loss: 1.8884
# Epoch 29/200
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7040 - val_loss: 1.8493
# Epoch 30/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.6901 - val_loss: 1.8224
# Epoch 31/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6754 - val_loss: 1.8074
# Epoch 32/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6627 - val_loss: 1.7796
# Epoch 33/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6471 - val_loss: 1.7566
# Epoch 34/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6357 - val_loss: 1.7484
# Epoch 35/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6215 - val_loss: 1.7493
# Epoch 36/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.6071 - val_loss: 1.7540
# Epoch 37/200
# 4/4 [==============================] - 0s 22ms/step - loss: 1.5917 - val_loss: 1.7591
# Epoch 38/200
# 4/4 [==============================] - 0s 23ms/step - loss: 1.5785 - val_loss: 1.7627
# Epoch 39/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.5681 - val_loss: 1.7681
# Epoch 40/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.5541 - val_loss: 1.7471
# Epoch 41/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.5392 - val_loss: 1.7286
# Epoch 42/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.5232 - val_loss: 1.7216
# Epoch 43/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.5077 - val_loss: 1.7078
# Epoch 44/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4946 - val_loss: 1.6986
# Epoch 45/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4837 - val_loss: 1.6873
# Epoch 46/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.4729 - val_loss: 1.6628
# Epoch 47/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4589 - val_loss: 1.6519
# Epoch 48/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4465 - val_loss: 1.6476
# Epoch 49/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4324 - val_loss: 1.6349
# Epoch 50/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4209 - val_loss: 1.6206
# Epoch 51/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4058 - val_loss: 1.5949
# Epoch 52/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3954 - val_loss: 1.5774
# Epoch 53/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3790 - val_loss: 1.5702
# Epoch 54/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.3655 - val_loss: 1.5607
# Epoch 55/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3495 - val_loss: 1.5589
# Epoch 56/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.3365 - val_loss: 1.5566
# Epoch 57/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3219 - val_loss: 1.5497
# Epoch 58/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.3070 - val_loss: 1.5329
# Epoch 59/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2926 - val_loss: 1.5178
# Epoch 60/200
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2791 - val_loss: 1.5200
# Epoch 61/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2636 - val_loss: 1.4932
# Epoch 62/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.2546 - val_loss: 1.4813
# Epoch 63/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.2345 - val_loss: 1.4856
# Epoch 64/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2231 - val_loss: 1.4543
# Epoch 65/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1986 - val_loss: 1.4425
# Epoch 66/200
# 4/4 [==============================] - 0s 17ms/step - loss: 1.1790 - val_loss: 1.4198
# Epoch 67/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1619 - val_loss: 1.3746
# Epoch 68/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1461 - val_loss: 1.3449
# Epoch 69/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1265 - val_loss: 1.3332
# Epoch 70/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1115 - val_loss: 1.3232
# Epoch 71/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0939 - val_loss: 1.3030
# Epoch 72/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0769 - val_loss: 1.2896
# Epoch 73/200
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0613 - val_loss: 1.2819
# Epoch 74/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0413 - val_loss: 1.2769
# Epoch 75/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0229 - val_loss: 1.2678
# Epoch 76/200
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0071 - val_loss: 1.2667
# Epoch 77/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9905 - val_loss: 1.2699
# Epoch 78/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9735 - val_loss: 1.2678
# Epoch 79/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9544 - val_loss: 1.2625
# Epoch 80/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9398 - val_loss: 1.2424
# Epoch 81/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9234 - val_loss: 1.2164
# Epoch 82/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9082 - val_loss: 1.1952
# Epoch 83/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8945 - val_loss: 1.1786
# Epoch 84/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8806 - val_loss: 1.1728
# Epoch 85/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8644 - val_loss: 1.1595
# Epoch 86/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8502 - val_loss: 1.1306
# Epoch 87/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8347 - val_loss: 1.1067
# Epoch 88/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8210 - val_loss: 1.0842
# Epoch 89/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8086 - val_loss: 1.0658
# Epoch 90/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7950 - val_loss: 1.0628
# Epoch 91/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7817 - val_loss: 1.0577
# Epoch 92/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7696 - val_loss: 1.0552
# Epoch 93/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7568 - val_loss: 1.0553
# Epoch 94/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7458 - val_loss: 1.0498
# Epoch 95/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7330 - val_loss: 1.0435
# Epoch 96/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7224 - val_loss: 1.0417
# Epoch 97/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.7099 - val_loss: 1.0281
# Epoch 98/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6992 - val_loss: 1.0137
# Epoch 99/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6892 - val_loss: 1.0075
# Epoch 100/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6778 - val_loss: 1.0101
# Epoch 101/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6678 - val_loss: 1.0083
# Epoch 102/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6571 - val_loss: 0.9993
# Epoch 103/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6490 - val_loss: 0.9797
# Epoch 104/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6385 - val_loss: 0.9683
# Epoch 105/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6308 - val_loss: 0.9493
# Epoch 106/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6230 - val_loss: 0.9289
# Epoch 107/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6117 - val_loss: 0.9188
# Epoch 108/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6023 - val_loss: 0.9093
# Epoch 109/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5947 - val_loss: 0.9064
# Epoch 110/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5859 - val_loss: 0.9009
# Epoch 111/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5772 - val_loss: 0.8977
# Epoch 112/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5668 - val_loss: 0.8979
# Epoch 113/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5574 - val_loss: 0.9035
# Epoch 114/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5490 - val_loss: 0.9134
# Epoch 115/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5421 - val_loss: 0.9192
# Epoch 116/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5341 - val_loss: 0.9194
# Epoch 117/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5293 - val_loss: 0.9163
# Epoch 118/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5223 - val_loss: 0.9074
# Epoch 119/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5157 - val_loss: 0.9026
# Epoch 120/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5094 - val_loss: 0.9018
# Epoch 121/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5028 - val_loss: 0.9055
# Epoch 122/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4981 - val_loss: 0.9020
# Epoch 123/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4901 - val_loss: 0.8935
# Epoch 124/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4816 - val_loss: 0.8847
# Epoch 125/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4733 - val_loss: 0.8808
# Epoch 126/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4688 - val_loss: 0.8755
# Epoch 127/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4631 - val_loss: 0.8659
# Epoch 128/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4575 - val_loss: 0.8553
# Epoch 129/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4507 - val_loss: 0.8470
# Epoch 130/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4439 - val_loss: 0.8433
# Epoch 131/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4373 - val_loss: 0.8367
# Epoch 132/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4309 - val_loss: 0.8245
# Epoch 133/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4262 - val_loss: 0.8216
# Epoch 134/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4195 - val_loss: 0.8240
# Epoch 135/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4134 - val_loss: 0.8289
# Epoch 136/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4075 - val_loss: 0.8340
# Epoch 137/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4027 - val_loss: 0.8342
# Epoch 138/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3976 - val_loss: 0.8295
# Epoch 139/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3921 - val_loss: 0.8284
# Epoch 140/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3879 - val_loss: 0.8230
# Epoch 141/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3832 - val_loss: 0.8167
# Epoch 142/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3774 - val_loss: 0.8129
# Epoch 143/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3726 - val_loss: 0.8136
# Epoch 144/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3684 - val_loss: 0.8116
# Epoch 145/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3642 - val_loss: 0.8076
# Epoch 146/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3589 - val_loss: 0.8034
# Epoch 147/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3552 - val_loss: 0.8024
# Epoch 148/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3507 - val_loss: 0.8050
# Epoch 149/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3465 - val_loss: 0.8093
# Epoch 150/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3414 - val_loss: 0.8128
# Epoch 151/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3370 - val_loss: 0.8109
# Epoch 152/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3337 - val_loss: 0.8047
# Epoch 153/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3289 - val_loss: 0.7991
# Epoch 154/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3245 - val_loss: 0.7980
# Epoch 155/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3201 - val_loss: 0.7996
# Epoch 156/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3171 - val_loss: 0.8003
# Epoch 157/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3134 - val_loss: 0.7941
# Epoch 158/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3077 - val_loss: 0.7834
# Epoch 159/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3053 - val_loss: 0.7751
# Epoch 160/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3012 - val_loss: 0.7759
# Epoch 161/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2978 - val_loss: 0.7792
# Epoch 162/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2952 - val_loss: 0.7804
# Epoch 163/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2916 - val_loss: 0.7806
# Epoch 164/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2877 - val_loss: 0.7803
# Epoch 165/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2849 - val_loss: 0.7789
# Epoch 166/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2811 - val_loss: 0.7773
# Epoch 167/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2788 - val_loss: 0.7768
# Epoch 168/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2763 - val_loss: 0.7777
# Epoch 169/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2729 - val_loss: 0.7805
# Epoch 170/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2693 - val_loss: 0.7819
# Epoch 171/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2710 - val_loss: 0.7851
# Epoch 172/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2685 - val_loss: 0.7844
# Epoch 173/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2633 - val_loss: 0.7804
# Epoch 174/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2592 - val_loss: 0.7756
# Epoch 175/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2565 - val_loss: 0.7730
# Epoch 176/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2528 - val_loss: 0.7705
# Epoch 177/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2518 - val_loss: 0.7694
# Epoch 178/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2499 - val_loss: 0.7691
# Epoch 179/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2468 - val_loss: 0.7696
# Epoch 180/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2425 - val_loss: 0.7743
# Epoch 181/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2386 - val_loss: 0.7778
# Epoch 182/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2351 - val_loss: 0.7788
# Epoch 183/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2328 - val_loss: 0.7784
# Epoch 184/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2303 - val_loss: 0.7752
# Epoch 185/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2275 - val_loss: 0.7717
# Epoch 186/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2243 - val_loss: 0.7723
# Epoch 187/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2226 - val_loss: 0.7717
# Epoch 188/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2210 - val_loss: 0.7704
# Epoch 189/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2175 - val_loss: 0.7683
# Epoch 190/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2161 - val_loss: 0.7674
# Epoch 191/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2148 - val_loss: 0.7683
# Epoch 192/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2124 - val_loss: 0.7719
# Epoch 193/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2102 - val_loss: 0.7760
# Epoch 194/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2085 - val_loss: 0.7760
# Epoch 195/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2065 - val_loss: 0.7769
# Epoch 196/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2051 - val_loss: 0.7757
# Epoch 197/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2030 - val_loss: 0.7732
# Epoch 198/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2000 - val_loss: 0.7751
# Epoch 199/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1991 - val_loss: 0.7782
# Epoch 200/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1984 - val_loss: 0.7780
# Model training completed and saved.

# %% [markdown]
# ### Test Inference

# %%
def generate_reply(input_text, max_reply_len=20):
    text = clean_text(input_text)
    seq = tokenizer.texts_to_sequences([text])
    seq = keras.preprocessing.sequence.pad_sequences(seq, maxlen=max_len_in, padding='post')

    # Encode input
    enc_model = keras.Model(encoder_inputs, state_h)
    enc_state = enc_model.predict(seq)

    # Decoder setup for inference
    dec_state_input = keras.Input(shape=(HIDDEN_DIM,))
    dec_x = dec_emb
    dec_outputs, dec_state = decoder_gru(dec_x, initial_state=dec_state_input)
    dec_out_tokens = decoder_dense(dec_outputs)
    dec_infer_model = keras.Model([decoder_inputs, dec_state_input], [dec_out_tokens, dec_state])

    # Generate
    target_seq_test = np.array([[word_index['start']]])
    stop_condition = False
    decoded_sentence = ""

    while not stop_condition:
        output_tokens, enc_state = dec_infer_model.predict([target_seq_test, enc_state])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = index_word.get(sampled_token_index, '')

        if sampled_word == 'end' or len(decoded_sentence.split()) > max_reply_len:
            stop_condition = True
        else:
            decoded_sentence += ' ' + sampled_word
            target_seq_test = np.array([[sampled_token_index]])

    return decoded_sentence.strip()

# ----------------------------------------------
# 9️⃣ Test example
# ----------------------------------------------
print("\nExample:")
print("You: turn on the fan")
print("Bot:", generate_reply("turn on the fan"))
# Out:
# Example:
# You: turn on the fan
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 647ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Bot: okay turning on the curtain

# %%
generate_reply("Hi")
# Out:
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 16ms/step
# 'hi there'

# %%
generate_reply("What can you do?")
# Out:
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 'i can help control your smart home devices'

# %%
generate_reply("Turn on the fridge")
# Out:
# 1/1 [==============================] - 1s 656ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 'okay turning on the cctv'

# %%
generate_reply("It's so hot")
# Out:
# 1/1 [==============================] - 1s 656ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 658ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 'i can help control your smart home devices'

# %%
generate_reply("Plants are dry")
# Out:
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 'i can help control your smart home devices'

# %%
generate_reply("it's dark")
# Out:
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 653ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 'just hanging out ready to help you'

# %%
generate_reply("Turn on the CCTV")
# Out:
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 658ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 'okay turning on the light'
