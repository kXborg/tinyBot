# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline

# Load dataset
df = pd.read_csv('../dataset/tiny_chat_dataset_large.csv')

# Prepare model
model = make_pipeline(
    TfidfVectorizer(),
    DecisionTreeClassifier(max_depth=10, random_state=42)
)

# Train model
model.fit(df['input_text'], df['reply_text'])
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=10, random_state=42))])

# %%
def chat(query):
    reply = model.predict([query])[0]
    print(f"User: {query}\nBot: {reply}")

# %%
chat("Hi")
chat("Hello there")
chat("Good morning TinyBot")
chat("How are you?")
chat("What's your name?")
chat("What can you do?")
chat("Turn on the light")
chat("Switch on the fan")
chat("Activate the dim light")
chat("Turn off the curtain")
chat("Open the curtain")
chat("Close the door")
chat("Is the fridge on?")
chat("Check the door sensor")
chat("Show me the camera")
chat("Is the light off?")
chat("It's too hot")
chat("It's dark")
chat("The plants are dry")
chat("The aquarium looks dirty")
chat("Start the hydroponic farm motor")
chat("Stop the hydroponic farm motor")
chat("Switch off the refrigerator")
chat("Turn off everything")
chat("Enable the fan for 10 minutes")
chat("Schedule the light at 7 PM")
chat("What’s the room temperature?")
chat("What’s the humidity?")
chat("Thanks")
chat("Thank you TinyBot")
chat("Bye")
chat("Good night")
chat("See you later")
chat("You are smart")
chat("You are dumb")
chat("Who made you?")
chat("Tell me a joke")
chat("How’s the day?")
chat("I’m bored")
chat("Can you dance?")
chat("Sing a song")
chat("Restart the system")
chat("What devices are connected?")
chat("List all devices")
chat("Can you check my home?")
chat("Report status")
chat("Everything okay?")
chat("Are you online?")
chat("Good evening")
chat("Turn on the fan and light")
chat("Turn off fan and fridge")
# Out:
# User: Hi
# Bot: done, phone charger is off.
# User: Hello there
# Bot: done, phone charger is off.
# User: Good morning TinyBot
# Bot: done, phone charger is off.
# User: How are you?
# Bot: done, phone charger is off.
# User: What's your name?
# Bot: done, phone charger is off.
# User: What can you do?
# Bot: done, phone charger is off.
# User: Turn on the light
# Bot: okay turning on the light.
# User: Switch on the fan
# Bot: done, fan is now on.
# User: Activate the dim light
# Bot: okay turning on the dim light.
# User: Turn off the curtain
# Bot: done, curtain is off.
# User: Open the curtain
# Bot: done, curtain is off.
# User: Close the door
# Bot: done, phone charger is off.
# User: Is the fridge on?
# Bot: done, phone charger is off.
# User: Check the door sensor
# Bot: done, phone charger is off.
# User: Show me the camera
# Bot: done, phone charger is off.
# User: Is the light off?
# Bot: done, phone charger is off.
# User: It's too hot
# Bot: done, phone charger is off.
# User: It's dark
# Bot: done, phone charger is off.
# User: The plants are dry
# Bot: done, phone charger is off.
# User: The aquarium looks dirty
# Bot: okay turning on the aquarium filter.
# User: Start the hydroponic farm motor
# Bot: okay turning on the hydroponic farm motor.
# User: Stop the hydroponic farm motor
# Bot: okay turning on the hydroponic farm motor.
# User: Switch off the refrigerator
# Bot: done, refrigerator is off.
# User: Turn off everything
# Bot: done, phone charger is off.
# User: Enable the fan for 10 minutes
# Bot: done, fan is now on.
# User: Schedule the light at 7 PM
# Bot: turning off the light.
# User: What’s the room temperature?
# Bot: done, phone charger is off.
# User: What’s the humidity?
# Bot: done, phone charger is off.
# User: Thanks
# Bot: done, phone charger is off.
# User: Thank you TinyBot
# Bot: done, phone charger is off.
# User: Bye
# Bot: done, phone charger is off.
# User: Good night
# Bot: done, phone charger is off.
# User: See you later
# Bot: done, phone charger is off.
# User: You are smart
# Bot: done, phone charger is off.
# User: You are dumb
# Bot: done, phone charger is off.
# User: Who made you?
# Bot: done, phone charger is off.
# User: Tell me a joke
# Bot: done, phone charger is off.
# User: How’s the day?
# Bot: done, phone charger is off.
# User: I’m bored
# Bot: done, phone charger is off.
# User: Can you dance?
# Bot: done, phone charger is off.
# User: Sing a song
# Bot: done, phone charger is off.
# User: Restart the system
# Bot: done, phone charger is off.
# User: What devices are connected?
# Bot: done, phone charger is off.
# User: List all devices
# Bot: done, phone charger is off.
# User: Can you check my home?
# Bot: done, phone charger is off.
# User: Report status
# Bot: done, phone charger is off.
# User: Everything okay?
# Bot: done, phone charger is off.
# User: Are you online?
# Bot: done, phone charger is off.
# User: Good evening
# Bot: done, phone charger is off.
# User: Turn on the fan and light
# Bot: done, fan is now on.
# User: Turn off fan and fridge
# Bot: done, fan is off.
